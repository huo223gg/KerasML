# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import random
import matplotlib.pyplot as plt


from matplotlib import pyplot

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(64, input_dim=1, activation='relu'))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='rmsprop', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)

# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['acc'], 'b', label='train acc')
acc_ax.plot(hist.history['val_acc'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# Using TensorFlow backend.
# Epoch 1/50
# 1000/1000 [==============================] - 1s 616us/step - loss: 1.4339
# Epoch 2/50
# 1000/1000 [==============================] - 0s 36us/step - loss: 1.0706
# Epoch 3/50
# 1000/1000 [==============================] - 0s 40us/step - loss: 0.8086
# Epoch 4/50
# 1000/1000 [==============================] - 0s 58us/step - loss: 0.5912
# Epoch 5/50
# 1000/1000 [==============================] - 0s 68us/step - loss: 0.4092
# Epoch 6/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.2667
# Epoch 7/50
# 1000/1000 [==============================] - 0s 77us/step - loss: 0.1671
# Epoch 8/50
# 1000/1000 [==============================] - 0s 39us/step - loss: 0.1069
# Epoch 9/50
# 1000/1000 [==============================] - 0s 57us/step - loss: 0.0803
# Epoch 10/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0668
# Epoch 11/50
# 1000/1000 [==============================] - 0s 57us/step - loss: 0.0533
# Epoch 12/50
# 1000/1000 [==============================] - 0s 35us/step - loss: 0.0410
# Epoch 13/50
# 1000/1000 [==============================] - 0s 73us/step - loss: 0.0308
# Epoch 14/50
# 1000/1000 [==============================] - 0s 37us/step - loss: 0.0225
# Epoch 15/50
# 1000/1000 [==============================] - 0s 43us/step - loss: 0.0163
# Epoch 16/50
# 1000/1000 [==============================] - 0s 48us/step - loss: 0.0121
# Epoch 17/50
# 1000/1000 [==============================] - 0s 53us/step - loss: 0.0101
# Epoch 18/50
# 1000/1000 [==============================] - 0s 41us/step - loss: 0.0094
# Epoch 19/50
# 1000/1000 [==============================] - 0s 38us/step - loss: 0.0093
# Epoch 20/50
# 1000/1000 [==============================] - 0s 43us/step - loss: 0.0094
# Epoch 21/50
# 1000/1000 [==============================] - 0s 38us/step - loss: 0.0092
# Epoch 22/50
# 1000/1000 [==============================] - 0s 54us/step - loss: 0.0093
# Epoch 23/50
# 1000/1000 [==============================] - 0s 40us/step - loss: 0.0093
# Epoch 24/50
# 1000/1000 [==============================] - 0s 41us/step - loss: 0.0093
# Epoch 25/50
# 1000/1000 [==============================] - 0s 37us/step - loss: 0.0093
# Epoch 26/50
# 1000/1000 [==============================] - 0s 46us/step - loss: 0.0092
# Epoch 27/50
# 1000/1000 [==============================] - 0s 36us/step - loss: 0.0093
# Epoch 28/50
# 1000/1000 [==============================] - 0s 55us/step - loss: 0.0093
# Epoch 29/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.009 - 0s 36us/step - loss: 0.0094
# Epoch 30/50
# 1000/1000 [==============================] - 0s 50us/step - loss: 0.0093
# Epoch 31/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0093
# Epoch 32/50
# 1000/1000 [==============================] - 0s 65us/step - loss: 0.0093
# Epoch 33/50
# 1000/1000 [==============================] - 0s 49us/step - loss: 0.0093
# Epoch 34/50
# 1000/1000 [==============================] - 0s 50us/step - loss: 0.0093
# Epoch 35/50
# 1000/1000 [==============================] - 0s 38us/step - loss: 0.0092
# Epoch 36/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0093
# Epoch 37/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0092
# Epoch 38/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0093
# Epoch 39/50
# 1000/1000 [==============================] - 0s 90us/step - loss: 0.0092
# Epoch 40/50
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.0093
# Epoch 41/50
# 1000/1000 [==============================] - 0s 74us/step - loss: 0.0093
# Epoch 42/50
# 1000/1000 [==============================] - 0s 38us/step - loss: 0.0093
# Epoch 43/50
# 1000/1000 [==============================] - 0s 48us/step - loss: 0.0092
# Epoch 44/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0093
# Epoch 45/50
# 1000/1000 [==============================] - 0s 46us/step - loss: 0.0092
# Epoch 46/50
# 1000/1000 [==============================] - 0s 42us/step - loss: 0.0093
# Epoch 47/50
# 1000/1000 [==============================] - 0s 43us/step - loss: 0.0093
# Epoch 48/50
# 1000/1000 [==============================] - 0s 46us/step - loss: 0.0093
# Epoch 49/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0093
# Epoch 50/50
# 1000/1000 [==============================] - 0s 46us/step - loss: 0.0093
# 100/100 [==============================] - 0s 2ms/step
# loss : 0.009890496954321861
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-c966576e17d8> in <module>()
#      46
#      47 loss_ax.plot(hist.history['loss'], 'y', label='train loss')
# ---> 48 loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
#      49
#      50 acc_ax.plot(hist.history['acc'], 'b', label='train acc')
#
# KeyError: 'val_loss'
